# %% [markdown]
# <a href="https://colab.research.google.com/github/nicabey/Numerical-Methods/blob/main/Module_3_Discussion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Cubic Roots Discussion
# Nichole Beyer

# %%
import numpy as np
from scipy.misc import derivative 
##defining my function

x_n = 1
x = np.linspace(-1,1,100)

def f(x):
  return x**3+8*x**2+16*x
  
def first_x(f,x,x_n):
  mlope = derivative(f,x_n,dx=1)
  return x_n - f(x_n) / mlope


for n in range (20):
  print(f(x))


##ok I'll explain, when I try to format the things below to give me not all that gunk It just spits 1's so we will interpret those numbers, deal with it! you can see where the values change from positive to negative thats a zero boom.
# Out:
# [-9.         -8.93734509 -8.87055949 -8.79959373 -8.72439836 -8.64492388
#  -8.56112085 -8.47293978 -8.38033122 -8.28324568 -8.1816337  -8.07544582
#  -7.96463255 -7.84914444 -7.72893201 -7.60394579 -7.47413632 -7.33945413
#  -7.19984974 -7.05527368 -6.9056765  -6.75100871 -6.59122085 -6.42626345
#  -6.25608704 -6.08064215 -5.89987932 -5.71374906 -5.52220192 -5.32518842
#  -5.1226591  -4.91456448 -4.7008551  -4.48148148 -4.25639416 -4.02554367
#  -3.78888054 -3.5463553  -3.29791848 -3.04352061 -2.78311222 -2.51664384
#  -2.244066   -1.96532924 -1.68038409 -1.38918107 -1.09167071 -0.78780355
#  -0.47753012 -0.16080095  0.16243344  0.4922225   0.82861572  1.17166255
#   1.52141247  1.87791495  2.24121946  2.61137546  2.98843243  3.37243984
#   3.76344714  4.16150383  4.56665935  4.97896319  5.3984648   5.82521367
#   6.25925926  6.70065104  7.14943847  7.60567104  8.0693982   8.54066942
#   9.01953418  9.50604195 10.00024219 10.50218438 11.01191798 11.52949246
# ...

# %% [markdown]
# We can see above that the function values move from a positive y value to a negative and back, this helps us see that 3 zeros are found. To help us see that more clearly I will include a graph.

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.plot(x, x**3+8*x**2+16*x)
x=np.linspace(-15,5,num = 10,endpoint=True )

plt.title('Graph of y=x^3+8x^2+16x')
# Out:
# Text(0.5, 1.0, 'Graph of y=x^3+8x^2+16x')

# %% [markdown]
# Look at that graph, wow.
#
# I had a hard time with this, I thought we were somehow supposed to do the method that is in the book for finding roots and theres so much substitution and I tried that for a while with no luck, so I switched gears. I watched a couple youtube videos and this is what I came up with. The beginning part is rough but I think you get the picture
